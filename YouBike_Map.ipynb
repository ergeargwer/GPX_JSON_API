# %% [markdown]
# <a href="https://colab.research.google.com/github/ergeargwer/GPX_JSON_API/blob/main/YouBike_Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.透過colab開發程式
# 2.取用google maps API ，api KEY 名稱為[Maps_API_Key]
# 3,取用youbike 站點名稱
# 4.讀取/content/drive/MyDrive/Youbike/youbike_log.csv youbike使用紀錄
# 5.透過視覺線條方式呈現借用予歸還的歷程
#  (1)在google maps 畫上空中弧線,弧線起點為[借車站],弧線終止點為[還車站],弧線呈現的速度取決於借用的[租借時數]欄位時間，
# 6.逐一將 youbike_log.csv 紀錄繪製線條呈現

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install folium geopy googlemaps
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40716 sha256=bb3b4b8646c625cb2ee74de888617c5f7279c636a7ff14e860edd2bda1e2cffd
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# ...

# %%
import pandas as pd
import folium
import googlemaps
import numpy as np
import time
from geopy.geocoders import GoogleV3
from geopy.extra.rate_limiter import RateLimiter
import branca
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# 設定 Google Maps API
Maps_API_Key = 'YOUR_GOOGLE_MAPS_API_KEY'  # 替換為您的實際 API 金鑰
gmaps = googlemaps.Client(key=Maps_API_Key)
geolocator = GoogleV3(api_key=Maps_API_Key, domain='maps.googleapis.com')
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d98129b63604> in <cell line: 3>()
#       1 # 設定 Google Maps API
#       2 Maps_API_Key = 'YOUR_GOOGLE_MAPS_API_KEY'  # 替換為您的實際 API 金鑰
# ----> 3 gmaps = googlemaps.Client(key=Maps_API_Key)
#       4 geolocator = GoogleV3(api_key=Maps_API_Key, domain='maps.googleapis.com')
#       5 geocode = RateLimiter(geolocator.geocode, min_delay_seconds=0.1)
#
# /usr/local/lib/python3.10/dist-packages/googlemaps/client.py in __init__(self, key, client_id, client_secret, timeout, connect_timeout, read_timeout, retry_timeout, requests_kwargs, queries_per_second, queries_per_minute, channel, retry_over_query_limit, experience_id, requests_session, base_url)
#     142
#     143         if key and not key.startswith("AIza"):
# --> 144             raise ValueError("Invalid API key provided.")
#     145
# ...
